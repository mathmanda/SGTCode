# %%
runfile SuperTriangle.py

# %%
n=2
G = SuperTriangle(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32c271f754ab> in <module>()
#       1 n=Integer(2)
# ----> 2 G = SuperTriangle(n)
#
# NameError: name 'SuperTriangle' is not defined

# %%
G.show()

L = G.laplacian_matrix()
M = matrix(linalg.pinv(L))
rs = G.spanning_trees_count()
print M 

print 'n*trace', 6*M.trace()

M,r = effresistance_matrix(G,zeroadjacents = False)
s = 0
for i in range(0,6):
    for j in range(i,6):
        s+=M[i,j]

print s/r
print M
# Out:
# Graphics object consisting of 16 graphics primitives
# [   0.41203703703703726 -0.0046296296296298575    -0.0046296296296293    -0.1435185185185185   -0.11574074074074096   -0.14351851851851868]
# [  -0.00462962962962958    0.18981481481481474   -0.03240740740740728 -0.0046296296296297005   -0.03240740740740742   -0.11574074074074076]
# [ -0.004629629629629555  -0.032407407407407454    0.18981481481481488   -0.11574074074074073  -0.032407407407407475  -0.004629629629629621]
# [  -0.14351851851851868 -0.0046296296296295635   -0.11574074074074096     0.4120370370370369  -0.004629629629629452   -0.14351851851851852]
# [  -0.11574074074074078   -0.03240740740740744   -0.03240740740740742  -0.004629629629629699    0.18981481481481485  -0.004629629629629539]
# [  -0.14351851851851857   -0.11574074074074064  -0.004629629629629664   -0.14351851851851866  -0.004629629629629449     0.4120370370370372]
# n*trace 10.8333333333333
# 10.8333333333333
# [ 0.0 33.0 33.0 60.0 45.0 60.0]
# ...

# %%
105*3/216*6
# Out:
# 35/4

# %%
st = G.spanning_trees_count()
r = resistance_distance(G,(0,((n+2)*(n+1)/2 - 1)))
print r*st
print st
print r
N = 100
factor(13586683392)
# Out:
# 13586683392.0
# 7242690816
# 1.87591652566
# 13586683392

# %% [raw]
# ((n+2)*(n+1)/2 - 1)

# %%
rprev=0
for i in range(1,40):
    G = SuperTriangle(i)
    r = resistance_distance(G,(0,((i+2)*(i+1)/2 - 1)))
    #denom = len(G.spanning_trees())
    #num = round(r*denom,0)
    #print num, '/', denom
    print i, r, r-rprev
    rprev = r
# Out:
# 1 0.666666666667 0.666666666667
# 2 1.11111111111 0.444444444444
# 3 1.42857142857 0.31746031746
# 4 1.67479674797 0.246225319396
# 5 1.87591652566 0.201119777695
# 6 2.0459311981 0.170014672439
# 7 2.19319090764 0.147259709535
# 8 2.32307651301 0.129885605369
# 9 2.4392596909 0.116183177897
# 10 2.54435826005 0.105098569149
# 11 2.64030463765 0.0959463776014
# 12 2.72856608517 0.0882614475171
# 13 2.81028300526 0.0817169200879
# 14 2.88635936767 0.076076362414
# 15 2.95752387184 0.0711645041641
# 16 3.02437252469 0.0668486528487
# 17 3.08739902483 0.0630265001474
# 18 3.14701691804 0.0596178932062
# 19 3.20357606161 0.0565591435754
# 20 3.25737506675 0.0537990051396
# 21 3.30867084322 0.0512957764683
# 22 3.35768602031 0.0490151770899
# 23 3.40461478707 0.0469287667608
# 24 3.44962753942 0.0450127523481
# 25 3.49287461519 0.0432470757716
# 26 3.53448932386 0.0416147086678
# 27 3.57459042496 0.0401011010953
# 28 3.61328417136 0.0386937464055
# 29 3.65066600605 0.0373818346875
# ...

# %%
Mlist = []
for v in M:
    Mlist+=list(v)
    
Ml = set(Mlist) 
Ml.remove(0)

# %%
mx = max(Ml)
mn = min(Ml)

# %%
print 'min', mn/m
print 'max', mx/m
# Out:
# min 0.666666666667
# max 1.42857142857

# %%
resistance_distance(G,(0,10))
# Out:
# 1.6747967479674808

# %%
16/21+2/3
# Out:
# 10/7

# %%
# Out:
# {3528.0, 3780.0, 4284.0, 5229.0, 5733.0, 7560.0}

# %%
G1 = SuperTriangle(1)
G2 = SuperTriangle(2)
G3 = SuperTriangle(3)
G4 = SuperTriangle(4)

print effresistance_matrix(G1,zeroadjacents = False)
print '==='
print effresistance_matrix(G2,zeroadjacents = False)
print '==='
print effresistance_matrix(G3,zeroadjacents = False)
print '==='
#print effresistance_matrix(G4)
print '==='
# Out:
# ([0.0 2.0 2.0]
# [2.0 0.0 2.0]
# [2.0 2.0 0.0], 3)
# ===
# ([ 0.0 33.0 33.0 60.0 45.0 60.0]
# [33.0  0.0 24.0 33.0 24.0 45.0]
# [33.0 24.0  0.0 45.0 24.0 33.0]
# [60.0 33.0 45.0  0.0 33.0 60.0]
# [45.0 24.0 24.0 33.0  0.0 33.0]
# [60.0 45.0 33.0 60.0 33.0  0.0], 54)
# ===
# ([   0.0 3213.0 3213.0 5229.0 4284.0 5229.0 7560.0 5733.0 5733.0 7560.0]
# [3213.0    0.0 2268.0 2772.0 2205.0 3528.0 5229.0 3528.0 3780.0 5733.0]
# [3213.0 2268.0    0.0 3528.0 2205.0 2772.0 5733.0 3780.0 3528.0 5229.0]
# [5229.0 2772.0 3528.0    0.0 2205.0 3780.0 3213.0 2268.0 3528.0 5733.0]
# [4284.0 2205.0 2205.0 2205.0    0.0 2205.0 4284.0 2205.0 2205.0 4284.0]
# [5229.0 3528.0 2772.0 3780.0 2205.0    0.0 5733.0 3528.0 2268.0 3213.0]
# [7560.0 5229.0 5733.0 3213.0 4284.0 5733.0    0.0 3213.0 5229.0 7560.0]
# [5733.0 3528.0 3780.0 2268.0 2205.0 3528.0 3213.0    0.0 2772.0 5229.0]
# [5733.0 3780.0 3528.0 3528.0 2205.0 2268.0 5229.0 2772.0    0.0 3213.0]
# ...

# %%
l = 3213/5292
l.n()
# Out:
# 0.607142857142857

# %%
m = (sqrt(5)-1)/2
m.n()
# Out:
# 0.618033988749895

# %%
effresistance_matrix(G4,zeroadjacents = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-5cd228d69f47> in <module>()
# ----> 1 effresistance_matrix(G4,zeroadjacents = False)
#
# /Users/amandafrancis/Dropbox/Research/SGT/CodeforWB/sgtcode/ComparisonCode.py in effresistance_matrix(G, numeric, rd, zeroadjacents)
#     269     R = d*e.transpose() + e*d.transpose() - 2* M
#     270
# --> 271     m = len(G.spanning_trees())
#     272     S = R * m
#     273
#
# /Applications/SageMath/local/lib/python2.7/site-packages/sage/graphs/graph.pyc in spanning_trees(self)
#    1547             forest.add_vertices(self.vertices())
#    1548             forest.add_edges(self.bridges())
# -> 1549             return _recursive_spanning_trees(Graph(self,immutable=False,loops=False), forest)
#    1550         else:
#    1551             return []
#
# ...

# %%
7560/5292
# Out:
# 10/7

# %%
G = SuperTriangle(4)

# %%
G.show()
# Out:
# Graphics object consisting of 46 graphics primitives

# %%
runfile ComparisonCode.py

# %%
r = resistance_distance(G,(0,10))
# Out:
# /Applications/SageMath/local/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
r
# Out:
# 1.6747967479674808

# %%
nsimplify(r - 2/3)
# Out:
# 124/123

# %%
124/4
# Out:
# 31

# %%
124/123+2/3
# Out:
# 206/123

# %%
denom=G.spanning_trees_count()

# %%
r*denom
# Out:
# 4560840.000000003

# %%
4560840/denom
# Out:
# 206/123

# %%
denom
# Out:
# 2723220

# %%
10/9-2/3
# Out:
# 4/9

# %%
15*15/28/28*448/1005
# Out:
# 60/469

# %%
25^2/2/24/31
# Out:
# 625/1488

# %%
s = 2000/2077 + 625/496
s
# Out:
# 73875/33232

# %%
1000^2/2077^2/s
# Out:
# 128000/1227507

# %%
1000*625/2077/496/s
# Out:
# 5000/18321

# %%
rprev=0
for i in range(41,50):
    G = SuperTriangle(i)
    r = resistance_distance(G,(0,((i+2)*(i+1)/2 - 1)))
    #denom = len(G.spanning_trees())
    #num = round(r*denom,0)
    #print num, '/', denom
    print i, r, r-rprev
    rprev = r
# Out:
# 41 4.02167986481 4.02167986481
# 42 4.04762595508 0.0259460902745
# 43 4.07297553001 0.0253495749244
# 44 4.09775540276 0.0247798727535
# 45 4.12199061832 0.0242352155608
# 46 4.1457046056 0.0237139872801
# 47 4.16891931357 0.0232147079613
# 48 4.1916553333 0.0227360197358
# 49 4.21393200778 0.0222766744797

# %%
for i in range(1,10):
    G = SuperTriangle(i)
    print i, G.spanning_trees_count()
# Out:
# 1 3
# 2 54
# 3 5292
# 4 2723220
# 5 7242690816
# 6 98719805835000
# 7 6861326937782575104
# 8 2423821818614367091537296
# 9 4342290918217084382837760000000

# %%
factor(5292)
# Out:
# 5292

# %%
G.show()
# Out:
# Graphics object consisting of 191 graphics primitives

# %%
runfile ResistorNetworkTransformations.py

# %%
G = SuperTriangle(3)
H = GraphtoWeighted(G)
H1 = YDelta(H, )
# Out:
# Graph on 10 vertices

# %%
H.plot(edge_labels = True)
# Out:
# Graphics object consisting of 326 graphics primitives

# %%
runfile ResistorNetworkTransformations.py

# %%
H = Graph()
H.add_edges([[1,2], [2,3], [3,1], [0,1], [0,5]])
H = GraphtoWeighted(H)
H.show()
H = YDelta(H, 1)
H.plot(edge_labels = True)
# Out:
# Graphics object consisting of 11 graphics primitives
# [0] [2] [3]
# Graphics object consisting of 15 graphics primitives

# %%
H = DeltaY(H,(0,2,3), (0,3,3), (2,3,3))
H.plot(edge_labels = True)
# Out:
# 3 3 3
# 3 2 0 5
# (3, 5) (2, 5) (0, 5)
# Graphics object consisting of 16 graphics primitives

# %%
H = YDelta(H,5)
H.plot(edge_labels = True)
# Out:
# [0] [2] [3]
# Graphics object consisting of 15 graphics primitives

# %%
runfile ResistorNetworkTransformations.py

# %%
runfile ComparisonCode.py

# %%
print H2.edges()
H3 = DeltaY(H2, (0,2,3), (0,3,3), (2,3,1))
H3.plot(edge_labels=True)
# Out:
# [(0, 2, 3), (0, 3, 3), (0, 4, 1), (2, 3, 1), (2, 3, 3)]
# 3 3 1
# 3 2 0 5
# (3, 5) (2, 5) (0, 5)
# Graphics object consisting of 16 graphics primitives

# %%
l = [2,3,4]
s = copy(l) 
s.remove(2)
print s, l
# Out:
# [3, 4] [2, 3, 4]

# %%
G = SuperTriangle(2)
A = G.adjacency_matrix()
s = Permutation([4,1,2,6,3,5])
S = s.to_matrix()
S = S.transpose()
Anew = S.transpose()*A*S
G1 = Graph(Anew)
G1.show()
M, r = effresistance_matrix(G1,zeroadjacents=False)
n = G1.num_verts()
print M, r
print G1.laplacian_matrix()
# Out:
# Graphics object consisting of 16 graphics primitives
# [ 0.0 24.0 24.0 33.0 45.0 33.0]
# [24.0  0.0 24.0 33.0 33.0 45.0]
# [24.0 24.0  0.0 45.0 33.0 33.0]
# [33.0 33.0 45.0  0.0 60.0 60.0]
# [45.0 33.0 33.0 60.0  0.0 60.0]
# [33.0 45.0 33.0 60.0 60.0  0.0] 54
# [ 4 -1 -1 -1  0 -1]
# [-1  4 -1 -1 -1  0]
# [-1 -1  4  0 -1 -1]
# [-1 -1  0  2  0  0]
# [ 0 -1 -1  0  2  0]
# [-1  0 -1  0  0  2]

# %%
L = G1.laplacian_matrix()
print L
Lnew = L[1:6,1:6]
Lstar = Lnew.inverse()
print Lstar
# Out:
# [ 4 -1 -1 -1  0 -1]
# [-1  4 -1 -1 -1  0]
# [-1 -1  4  0 -1 -1]
# [-1 -1  0  2  0  0]
# [ 0 -1 -1  0  2  0]
# [-1  0 -1  0  0  2]
# [  4/9   2/9   2/9   1/3   1/9]
# [  2/9   4/9   1/9   1/3   2/9]
# [  2/9   1/9 11/18   1/6  1/18]
# [  1/3   1/3   1/6   5/6   1/6]
# [  1/9   2/9  1/18   1/6 11/18]

# %%
d = Lstar.diagonal()
d = matrix(d).transpose()
dnew = [0]+list(d.transpose()[0])
e = allonesvector(5)

ER = d*e.transpose() + e*d.transpose()-2*Lstar
ER =  list(d.transpose())+list(ER) 
ER = [dnew] + list(matrix(ER).transpose())
ER = matrix(ER)
print ER
# Out:
# [    0   4/9   4/9 11/18   5/6 11/18]
# [  4/9     0   4/9 11/18 11/18   5/6]
# [  4/9   4/9     0   5/6 11/18 11/18]
# [11/18 11/18   5/6     0  10/9  10/9]
# [  5/6 11/18 11/18  10/9     0  10/9]
# [11/18   5/6 11/18  10/9  10/9     0]
