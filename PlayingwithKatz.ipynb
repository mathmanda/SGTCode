# %%
runfile KatzMethods.py

# %%
runfile ComparisonCode.py

# %%
l = comparegraphsofsize(6)
# Out:
# 0  bad cutoff scores
# 1  exceptions
# /Applications/SageMath/local/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
#G = l[1][0]
#G.show()

G = Graph()
G.add_edges([[0,1],[1,2],[2,3]])
G.show()
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
Katzmatrix(G,.3)
# Out:
# [ 0.000000000000000  0.000000000000000  0.121934697195502 0.0365804091586506]
# [ 0.000000000000000  0.000000000000000  0.000000000000000  0.121934697195502]
# [ 0.121934697195502  0.000000000000000  0.000000000000000  0.000000000000000]
# [0.0365804091586506  0.121934697195502  0.000000000000000  0.000000000000000]

# %%
rho = G.spectral_radius()
print rho
alpha = 1/rho[0]
alpha
print alpha
# Out:
# (1.6180339886704431, 1.618033988780243)
# 0.618033988780243

# %%
#Katzmethod(G,.41)

Katzmethod(G,alpha/2)
#Cutoff value!
# Out:
# [(0.0408340653863362, (0, 3)),
#  (0.132141811381367, (0, 2)),
#  (0.132141811381367, (1, 3))]

# %%
maxcn(G)
# Out:
# [(0, 2), (1, 3)]

# %%
lowresist(G,numeric = false)
# Out:
# [(2, (0, 2)), (2, (1, 3)), (3, (0, 3))]

# %%
list5 = n_Atlas('5 -c')
G = list5[0]
len(list5)
# Out:
# 21

# %%
for G in list5:
        #rho = G.spectral_radius()
        #beta = 1/rho[0]
        print '============'
        G.show()
        print 'Max common neighbors'
        print maxcn(G)
        print 'Katz'
        print Katzmethod(G,.2)
        #print 'ER'
        #print lowresist(G, numeric=false)
# Out:
# ...
# Graphics object consisting of 10 graphics primitives
# Max common neighbors
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Katz
# [(0.0476190476190476, (0, 1)), (0.0476190476190476, (0, 2)), (0.0476190476190476, (0, 3)), (0.0476190476190476, (1, 2)), (0.0476190476190476, (1, 3)), (0.0476190476190476, (2, 3))]
# ...
# Graphics object consisting of 10 graphics primitives
# Max common neighbors
# [(0, 1), (0, 2), (1, 2), (3, 4)]
# Katz
# [(0.00948766603415560, (1, 3)), (0.00948766603415560, (2, 3)), (0.0455407969639469, (1, 2)), (0.0474383301707780, (0, 1)), (0.0474383301707780, (0, 2)), (0.0474383301707780, (3, 4))]
# ...
# Graphics object consisting of 11 graphics primitives
# Max common neighbors
# [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3)]
# Katz
# [(0.0487804878048781, (1, 2)), (0.0609756097560976, (0, 1)), (0.0609756097560976, (0, 2)), (0.0609756097560976, (1, 3)), (0.0609756097560976, (2, 3))]
# ...
# Graphics object consisting of 11 graphics primitives
# Max common neighbors
# ...
